# %%
import os
from dotenv import load_dotenv
import boto3
import pandas as pd

load_dotenv()
# Out:
# True

# %%
os.chdir("/home/jterryc/zrive-ds-JTC/src/module_7/src")

# %%
os.getcwd()
# Out:
# '/home/jterryc/zrive-ds-JTC/src/module_7/src'

# %%
# Read keys from environment (Zrive keys)
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")
bucket = os.getenv("S3_BUCKET")

# Create boto3 client using those keys
s3_client = boto3.client(
    "s3",
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

# %%
response = s3_client.list_objects_v2(Bucket=bucket)
model_s3_key = response["Contents"][-1]["Key"]
model_name = model_s3_key.split("/")[-1]

# %%
os.chdir("/home/jterryc/zrive-ds-JTC/src/module_7/src")
local_path = os.path.join("/home/jterryc/zrive-ds-JTC/src/module_7/src", f"bin/{model_name}")
local_path
# Out:
# '/home/jterryc/zrive-ds-JTC/src/module_7/src/bin/model.joblib'

# %%
s3_client.download_file(
    Bucket=bucket,
    Key=model_s3_key,
    Filename=local_path
)

# %%
os.getcwd()
# Out:
# '/home/jterryc/zrive-ds-JTC/src/module_7/src'

# %%
model_path = '/home/jterryc/zrive-ds-JTC/src/module_7/src/bin/model.joblib'

# %%
import joblib

model = joblib.load(model_path)
model
# Out:
# RandomForestRegressor()

# %%
os.listdir()
# Out:
# ['data', 'basket_model', 'bin', 'app.py', '__pycache__', 'module_7.ipynb']

# %%
from basket_model.basket_model import BasketModel
from basket_model.feature_store import FeatureStore
import pandas as pd

feature_store = FeatureStore()
model = BasketModel()

# %%
orders = pd.read_parquet('/home/jterryc/zrive-ds-JTC/src/module_7/src/data/orders.parquet')
user_id = orders.user_id.iloc[10]
features = feature_store.get_features(user_id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/zrive-ds-JTC/src/module_7/src/basket_model/feature_store.py:32, in FeatureStore.get_features(self, user_id)
#      31 try:
# ---> 32     features = self.feature_store.loc[[user_id]]
#      33 except Exception as exception:
#
# File ~/.cache/pypoetry/virtualenvs/zrive-ds-PGs8NAUg-py3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.cache/pypoetry/virtualenvs/zrive-ds-PGs8NAUg-py3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1418         raise ValueError("Cannot index with multidimensional key")
# ...

# %%
user_id
# Out:
# '20ee168402deec23bdfae7d1ca7cc12018fd86577d1bb32621dddfc15318254829ac50e39fbd1f92a59907c59d430af5a15aad6743616367ff88678291de41ea'

# %%
model.predict(features).mean()
# Out:
# /home/jterryc/.cache/pypoetry/virtualenvs/zrive-ds-PGs8NAUg-py3.11/lib/python3.11/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# 47.156951045104535
